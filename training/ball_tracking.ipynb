# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# Requirement already satisfied: roboflow in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (1.2.6)
# Requirement already satisfied: certifi in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (3.10.5)
# Requirement already satisfied: numpy>=1.18.5 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (2.2.6)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (4.59.1)
# Requirement already satisfied: packaging>=20.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from requests->roboflow) (3.4.3)
# Requirement already satisfied: ultralytics in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (8.3.184)
# Requirement already satisfied: numpy>=1.23.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (3.10.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (2.3.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from ultralytics) (2.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %% [markdown]
# # Dataset

# %%
from roboflow import Roboflow
from ultralytics import YOLO


rf = Roboflow(api_key="APIKEY_HERE")
project = rf.workspace("ball-tracking-vcxpr").project("ball-tracker-debug-5t5hd")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Ball-tracker-debug-5 to yolov11:: 100%|██████████| 59918/59918 [00:23<00:00, 2501.52it/s]
# Extracting Dataset Version Zip to Ball-tracker-debug-5 in yolov11:: 100%|██████████| 2246/2246 [00:00<00:00, 10848.67it/s]

# %%
import shutil
file_path = "Ball-tracker-debug-5"

try:
    shutil.move(f"{file_path}/train",  f"{file_path}/{file_path}/train")
    shutil.move(f"{file_path}/test",  f"{file_path}/{file_path}/test")
    shutil.move(f"{file_path}/valid",  f"{file_path}/{file_path}/valid")
    shutil.move(f"{file_path}/data.yaml",  f"{file_path}/{file_path}/data.yaml")
    print("moved succesfully")
except:
    print("error")
    pass
# Out:
# moved succesfully

# %% [markdown]
# # Train Command

# %%
# !yolo task=detect mode=train model=yolo11m.pt data="Ball-tracker-debug-5/Ball-tracker-debug-5/data.yaml" epochs=100 imgsz=640 batch=16 name="yolov11m-ball-tracker"
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo1
# New https://pypi.org/project/ultralytics/8.3.193 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.184 🚀 Python-3.11.0 torch-2.8.0 CPU (Apple M3 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Ball-tracker-debug-5/Ball-tracker-debug-5/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov11m-ball-tracker, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/yolov11m-ball-tracker, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,053,779 parameters, 20,053,763 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 169.9±73.1 MB/s, size: 52.3 KB)
# train: Scanning /Users/ethan/Documents/Coding/Python Projects/Pickle CV/training
# train: New cache created: /Users/ethan/Documents/Coding/Python Projects/Pickle CV/training/Ball-tracker-debug-5/Ball-tracker-debug-5/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 356.8±66.3 MB/s, size: 57.5 KB)
# val: Scanning /Users/ethan/Documents/Coding/Python Projects/Pickle CV/training/B
# val: New cache created: /Users/ethan/Documents/Coding/Python Projects/Pickle CV/training/Ball-tracker-debug-5/Ball-tracker-debug-5/valid/labels.cache
# Plotting labels to runs/detect/yolov11m-ball-tracker/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/yolov11m-ball-tracker
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      2.979      12.93      1.086         26        640:  ^C
#       1/100         0G      2.979      12.93      1.086         26        640:
# Traceback (most recent call last):
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/bin/yolo", line 9, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 986, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/engine/model.py", line 799, in train
#     self.trainer.train()
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 229, in train
#     self._do_train(world_size)
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 406, in _do_train
#     loss, self.loss_items = self.model(batch)
#                             ^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py", line 138, in forward
#     return self.loss(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py", line 337, in loss
#     preds = self.forward(batch["img"]) if preds is None else preds
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py", line 139, in forward
#     return self.predict(x, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py", line 157, in predict
#     return self._predict_once(x, profile, visualize, embed)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/nn/tasks.py", line 180, in _predict_once
#     x = m(x)  # run
#         ^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/nn/modules/head.py", line 120, in forward
#     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#                                          ^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py", line 244, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/container.py", line 244, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/ultralytics/nn/modules/conv.py", line 80, in forward
#     return self.act(self.bn(self.conv(x)))
#                             ^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py", line 548, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/ethan/Documents/Coding/Python Projects/Pickle CV/.venv/lib/python3.11/site-packages/torch/nn/modules/conv.py", line 543, in _conv_forward
#     return F.conv2d(
#            ^^^^^^^^^
# KeyboardInterrupt
